# %% [markdown]
# # Appendix B

# %%
import requests
import json
from myst_nb import glue

def barrier_extent(barrier_type):

    request = 'https://features.hillcrestgeo.ca/bcfishpass/functions/postgisftw.wcrp_barrier_extent/items.json?watershed_group_code=BULK&barrier_type=' + barrier_type

    response_api = requests.get(request)
    parse = response_api.text
    result = json.loads(parse)

    blocked_km = result[0]['all_habitat_blocked_km']
    blocked_pct = result[0]['all_habitat_blocked_pct']

    return blocked_km, blocked_pct

def barrier_count(barrier_type):
    request = 'https://features.hillcrestgeo.ca/bcfishpass/functions/postgisftw.wcrp_barrier_count/items.json?watershed_group_code=BULK&barrier_type=' + barrier_type

    response_api = requests.get(request)
    parse = response_api.text
    result = json.loads(parse)

    n_passable = result[0]['n_passable']
    n_barrier = result[0]['n_barrier']
    n_potential = result[0]['n_potential']
    n_unknown = result[0]['n_unknown']

    sum_bar = (n_passable, n_barrier, n_potential, n_unknown)

    return n_passable, n_barrier, n_potential, n_unknown, sum(sum_bar)

def barrier_severity(barrier_type):

    request = 'https://features.hillcrestgeo.ca/bcfishpass/functions/postgisftw.wcrp_barrier_severity/items.json?watershed_group_code=BULK&barrier_type=' + barrier_type

    response_api = requests.get(request)
    parse = response_api.text
    result = json.loads(parse)

    n_assessed_barrier = result[0]['n_assessed_barrier']
    n_assess_total = result[0]['n_assess_total']
    pct_assessed_barrier = result[0]['pct_assessed_barrier']

    return n_assessed_barrier, n_assess_total, pct_assessed_barrier

def watershed_connectivity(habitat_type):

    request = 'https://features.hillcrestgeo.ca/bcfishpass/functions/postgisftw.wcrp_watershed_connectivity_status/items.json?watershed_group_code=BULK&barrier_type=' + habitat_type

    response_api = requests.get(request)
    parse = response_api.text
    result = json.loads(parse)

    connect_stat = result[0]['connectivity_status']

    return str(round(connect_stat))

import warnings

warnings.filterwarnings('ignore')

total = 526.95 #total km in HORS
access = round(total * (int(watershed_connectivity("ALL"))/100),2)
gain = round((total*0.96)-access,2)

glue("gain", str(gain))
# Out:
# '126.47'

# %% [markdown]
# ```{include} ../content/appendixb-md.md
# :start-after: "# Appendix B"
# :end-before: "The barrier prioritization process comprises three stages:"
# ```

# %%
    #table 16----------------------------------------------------------------------
    #--------------------------------------------------------------------------

import pandas as pd
import numpy as np
import matplotlib as mpl
import warnings

warnings.filterwarnings('ignore')

total = 526.95 #total km in HORS
access = round(total * (int(watershed_connectivity("ALL"))/100),2)
gain = round((total*0.96)-access,2)

df = pd.DataFrame({"Habitat Type":["Spawning and Rearing"],
                   "Currently accessible (km)":[str(access)],
                   "Total": [str(total)],
                   "Current Connectivity Status":[str(watershed_connectivity("ALL"))+"%"],
                   "Goal": ["96%"],
                   "Gain required (km)": [str(gain)]
                   })

data = df.style.hide_index().set_properties(**{'text-align': 'left'})

data.set_table_styles(
[dict(selector = 'th', props=[('text-align', 'left')])])

glue("Table16", data)
# Out:
# <style  type="text/css" >
#     #T_a7fff7c6_967e_11ed_a026_b445066bfd9b th {
#           text-align: left;
#     }#T_a7fff7c6_967e_11ed_a026_b445066bfd9brow0_col0,#T_a7fff7c6_967e_11ed_a026_b445066bfd9brow0_col1,#T_a7fff7c6_967e_11ed_a026_b445066bfd9brow0_col2,#T_a7fff7c6_967e_11ed_a026_b445066bfd9brow0_col3,#T_a7fff7c6_967e_11ed_a026_b445066bfd9brow0_col4,#T_a7fff7c6_967e_11ed_a026_b445066bfd9brow0_col5{
#             text-align:  left;
#         }</style><table id="T_a7fff7c6_967e_11ed_a026_b445066bfd9b" ><thead>    <tr>        <th class="col_heading level0 col0" >Habitat Type</th>        <th class="col_heading level0 col1" >Currently accessible (km)</th>        <th class="col_heading level0 col2" >Total</th>        <th class="col_heading level0 col3" >Current Connectivity Status</th>        <th class="col_heading level0 col4" >Goal</th>        <th class="col_heading level0 col5" >Gain required (km)</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a7fff7c6_967e_11ed_a026_b445066bfd9brow0_col0" class="data row0 col0" >Spawning and Rearing</td>
#                         <td id="T_a7fff7c6_967e_11ed_a026_b445066bfd9brow0_col1" class="data row0 col1" >379.4</td>
#                         <td id="T_a7fff7c6_967e_11ed_a026_b445066bfd9brow0_col2" class="data row0 col2" >526.95</td>
#                         <td id="T_a7fff7c6_967e_11ed_a026_b445066bfd9brow0_col3" class="data row0 col3" >72%</td>
#                         <td id="T_a7fff7c6_967e_11ed_a026_b445066bfd9brow0_col4" class="data row0 col4" >96%</td>
#                         <td id="T_a7fff7c6_967e_11ed_a026_b445066bfd9brow0_col5" class="data row0 col5" >126.47</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ```{glue:figure} Table16
# :name: "table16"
#
# *Spawning and rearing habitat connectivity gain requirements to meet WCRP goals in the Horsefly River watershed. The measures of currently accessible and total habitat values are derived from the Intrinsic Potential habitat model described in Appendix B.*
# ```

# %% [markdown]
# ```{include} ../content/appendixb-md.md
# :start-after: "rearing habitat ({numref}`table16`):"
# :end-before: "{glue:text}`inter_num` barriers on the intermediate"
# ```

# %%
data = pd.read_csv('../tables/Table17.csv', index_col=False)
data = data.replace(np.nan, '', regex=True)

data = data.style.hide_index().set_properties(**{'text-align': 'left'})

data.set_table_styles(
[dict(selector = 'th', props=[('text-align', 'left')])])

glue("Table17", data)
# Out:
# <style  type="text/css" >
#     #T_a809676e_967e_11ed_a2fc_b445066bfd9b th {
#           text-align: left;
#     }#T_a809676e_967e_11ed_a2fc_b445066bfd9brow0_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow0_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow0_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow0_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow1_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow1_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow1_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow1_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow2_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow2_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow2_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow2_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow3_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow3_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow3_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow3_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow4_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow4_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow4_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow4_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow5_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow5_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow5_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow5_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow6_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow6_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow6_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow6_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow7_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow7_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow7_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow7_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow8_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow8_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow8_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow8_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow9_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow9_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow9_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow9_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow10_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow10_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow10_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow10_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow11_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow11_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow11_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow11_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow12_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow12_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow12_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow12_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow13_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow13_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow13_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow13_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow14_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow14_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow14_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow14_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow15_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow15_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow15_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow15_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow16_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow16_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow16_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow16_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow17_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow17_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow17_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow17_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow18_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow18_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow18_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow18_col3,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow19_col0,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow19_col1,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow19_col2,#T_a809676e_967e_11ed_a2fc_b445066bfd9brow19_col3,#T_a809676e_967e_11ed_a2fc_b445066b ...
#             text-align:  left;
#         }</style><table id="T_a809676e_967e_11ed_a2fc_b445066bfd9b" ><thead>    <tr>        <th class="col_heading level0 col0" >ID</th>        <th class="col_heading level0 col1" >Stream name</th>        <th class="col_heading level0 col2" >Reason for removal from prioritization </th>        <th class="col_heading level0 col3" >Comments</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a809676e_967e_11ed_a2fc_b445066bfd9brow0_col0" class="data row0 col0" >
#   1001805665
#   </td>
#                         <td id="T_a809676e_967e_11ed_a2fc_b445066bfd9brow0_col1" class="data row0 col1" >
#   Canyon Creek
#   </td>
#                         <td id="T_a809676e_967e_11ed_a2fc_b445066bfd9brow0_col2" class="data row0 col2" >
#   Structure doesn't exist
#   </td>
#                         <td id="T_a809676e_967e_11ed_a2fc_b445066bfd9brow0_col3" class="data row0 col3" >
#   Adjacent landowner indicated that this crossing does not exist.
#   Quad access site that Dallas may try to get back to.
#   </td>
#             </tr>
#             <tr>
#                                 <td

# %% [markdown]
# ```{glue:figure} Table17
# :name: "table17"
#
# *List of crossings that were removed from the barrier prioritization list following field assessment. Crossings include those prioritized as part of the first iteration of the intermediate barrier list and additional sites selected by 2021 field crews that were removed following discussion with the planning team due to these structures not existing, being passable, not being associated with usable habitat, or deemed not feasible to remediate because of logistic considerations.*
# ```

# %%
data = pd.read_csv('../tables/table18.csv', index_col=False)

data = data.replace(np.nan, '', regex=True)

data = data.style.hide_index().set_properties(**{'text-align': 'left'})

data.set_table_styles(
[dict(selector = 'th', props=[('text-align', 'left')])])

#num of rows
num_p = len(data.index)

glue("Table18", data)
glue("inter_num", num_p)
# Out:
# <style  type="text/css" >
#     #T_a81e141a_967e_11ed_8a96_b445066bfd9b th {
#           text-align: left;
#     }#T_a81e141a_967e_11ed_8a96_b445066bfd9brow0_col0,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow0_col1,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow0_col2,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow0_col3,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow0_col4,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow0_col5,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow0_col6,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow0_col7,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow0_col8,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow0_col9,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow1_col0,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow1_col1,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow1_col2,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow1_col3,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow1_col4,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow1_col5,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow1_col6,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow1_col7,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow1_col8,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow1_col9,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow2_col0,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow2_col1,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow2_col2,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow2_col3,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow2_col4,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow2_col5,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow2_col6,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow2_col7,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow2_col8,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow2_col9,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow3_col0,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow3_col1,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow3_col2,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow3_col3,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow3_col4,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow3_col5,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow3_col6,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow3_col7,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow3_col8,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow3_col9,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow4_col0,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow4_col1,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow4_col2,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow4_col3,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow4_col4,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow4_col5,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow4_col6,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow4_col7,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow4_col8,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow4_col9,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow5_col0,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow5_col1,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow5_col2,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow5_col3,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow5_col4,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow5_col5,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow5_col6,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow5_col7,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow5_col8,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow5_col9,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow6_col0,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow6_col1,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow6_col2,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow6_col3,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow6_col4,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow6_col5,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow6_col6,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow6_col7,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow6_col8,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow6_col9,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow7_col0,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow7_col1,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow7_col2,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow7_col3,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow7_col4,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow7_col5,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow7_col6,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow7_col7,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow7_col8,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow7_col9,#T_a81e141a_967e_11ed_8a96_b445066bfd9brow8_col0,#T_a81e141a_967e_11ed_8a96 ...
# 53

# %% [markdown]
# ```{glue:figure} Table18
# :figwidth: 1000px
# :align: left
# :name: "table18"
#
# *Updated intermediate barrier list resulting from the second barrier prioritization analysis in the Bulkley River watershed. After assessing the potential barriers on the first iteration of the intermediate list (during 2021 field season) and either identifying them as remediation priorities or eliminating them from consideration (e.g., because they passed fish or did hot have suitable habitat upstream), the remaining potential barriers in the watershed were re-prioritized. The barriers on this list were prioritized to exceed the connectivity goals of the plan. Barriers highlighted in the same colour represent sets of barriers that have been prioritized as a group. In the Barrier Status column, P = potential barrier and B = confirmed barrier. All barrier assessment data is compiled from the BC Provincial Stream Crossing Inventory System.*
# ```

# %%
data = pd.read_csv('../tables/priority_barriers.csv', index_col=False)

#pd.options.display.max_columns=10

data = data.replace(np.nan, '', regex=True)

data = data.style.hide_index().set_properties(**{'text-align': 'left'})

data.set_table_styles(
[dict(selector = 'th', props=[('text-align', 'left')])])

#num of rows
num_p = len(data.index)

glue("Table19", data)
glue("prior_num", num_p)
# Out:
# <style  type="text/css" >
#     #T_a832b3b0_967e_11ed_8681_b445066bfd9b th {
#           text-align: left;
#     }#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col0,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col1,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col2,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col3,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col4,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col5,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col6,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col7,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col8,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col9,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col10,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col11,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col12,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow0_col13,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col0,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col1,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col2,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col3,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col4,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col5,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col6,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col7,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col8,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col9,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col10,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col11,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col12,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow1_col13,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col0,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col1,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col2,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col3,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col4,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col5,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col6,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col7,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col8,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col9,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col10,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col11,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col12,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow2_col13,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col0,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col1,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col2,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col3,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col4,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col5,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col6,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col7,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col8,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col9,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col10,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col11,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col12,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow3_col13,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col0,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col1,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col2,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col3,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col4,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col5,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col6,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col7,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col8,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col9,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col10,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col11,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col12,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow4_col13,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow5_col0,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow5_col1,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow5_col2,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow5_col3,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow5_col4,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow5_col5,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow5_col6,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow5_col7,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow5_col8,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow5_col9,#T_a832b3b0_967e_11ed_8681_b445066bfd9brow5_col10,#T_a8 ...
# 20

# %% [markdown]
# ```{glue:figure} Table19
# :figwidth: 1100px
# :align: left
# :name: "table19"
#
#
# *The Bulkley River watershed priority barrier list, which includes barriers that have undergone field assessment, been reviewed by the planning team, and selected to pursue for proactive remediation.*
# ```

# %% [markdown]
# ```{include} ../content/appendixb-md.md
# :start-after: "please see Mazany-Wright et al. 2021a."
# :end-before: "Based on the results of the prioritization analysis"
# ```

# %%
def df_style(val):
    return "font-weight: bold"


data = pd.read_csv('../tables/Table20.csv', index_col=False)

data = data.replace(np.nan, '', regex=True)

last_row = pd.IndexSlice[data.index[data.index == 2], :]

data = data.style.applymap(df_style, subset=last_row).hide_index().set_properties(**{'text-align': 'left'})

data.set_table_styles(
[dict(selector = 'th', props=[('text-align', 'left')])])

glue("Table20", data)
# Out:
# <style  type="text/css" >
#     #T_a841cc5e_967e_11ed_82a3_b445066bfd9b th {
#           text-align: left;
#     }#T_a841cc5e_967e_11ed_82a3_b445066bfd9brow0_col0,#T_a841cc5e_967e_11ed_82a3_b445066bfd9brow0_col1,#T_a841cc5e_967e_11ed_82a3_b445066bfd9brow0_col2,#T_a841cc5e_967e_11ed_82a3_b445066bfd9brow0_col3,#T_a841cc5e_967e_11ed_82a3_b445066bfd9brow1_col0,#T_a841cc5e_967e_11ed_82a3_b445066bfd9brow1_col1,#T_a841cc5e_967e_11ed_82a3_b445066bfd9brow1_col2,#T_a841cc5e_967e_11ed_82a3_b445066bfd9brow1_col3{
#             text-align:  left;
#         }#T_a841cc5e_967e_11ed_82a3_b445066bfd9brow2_col0,#T_a841cc5e_967e_11ed_82a3_b445066bfd9brow2_col1,#T_a841cc5e_967e_11ed_82a3_b445066bfd9brow2_col2,#T_a841cc5e_967e_11ed_82a3_b445066bfd9brow2_col3{
#             font-weight:  bold;
#             text-align:  left;
#         }</style><table id="T_a841cc5e_967e_11ed_82a3_b445066bfd9b" ><thead>    <tr>        <th class="col_heading level0 col0" >Field assessment</th>        <th class="col_heading level0 col1" >Cost per barrier</th>        <th class="col_heading level0 col2" >Count</th>        <th class="col_heading level0 col3" >Total costs</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a841cc5e_967e_11ed_82a3_b445066bfd9brow0_col0" class="data row0 col0" >
#   Barrier Assessment
#   </td>
#                         <td id="T_a841cc5e_967e_11ed_82a3_b445066bfd9brow0_col1" class="data row0 col1" >
#    $230
#   </td>
#                         <td id="T_a841cc5e_967e_11ed_82a3_b445066bfd9brow0_col2" class="data row0 col2" >23</td>
#                         <td id="T_a841cc5e_967e_11ed_82a3_b445066bfd9brow0_col3" class="data row0 col3" >
#    $5,290
#   </td>
#             </tr>
#             <tr>
#                                 <td id="T_a841cc5e_967e_11ed_82a3_b445066bfd9brow1_col0" class="data row1 col0" >
#   Habitat Confirmation
#   </td>
#                         <td id="T_a841cc5e_967e_11ed_82a3_b445066bfd9brow1_col1" class="data row1 col1" >
#    $3,000
#   </td>
#                         <td id="T_a841cc5e_967e_11ed_82a3_b445066bfd9brow1_col2" class="data row1 col2" >30</td>
#                         <td id="T_a841cc5e_967e_11ed_82a3_b445066bfd9brow1_col3" class="data row1 col3" >
#    $90,000
#   </td>
#             </tr>
#             <tr>
#                                 <td id="T_a841cc5e_967e_11ed_82a3_b445066bfd9brow2_col0" class="data row2 col0" >
#   Total:
#   </td>
#                         <td id="T_a841cc5e_967e_11ed_82a3_b445066bfd9brow2_col1" class="data row2 col1" ></td>
#                         <td id="T_a841cc5e_967e_11ed_82a3_b445066bfd9brow2_col2" class="data row2 col2" >53</td>
#                         <td id="T_a841cc5e_967e_11ed_82a3_b445066bfd9brow2_col3" class="data row2 col3" >
#    $95,290
#   </td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ```{glue:figure} Table20
# :name: "table20"
#
# *Field assessment requirements for the intermediate barrier list in the Bulkley River watershed. The cost per barrier values are estimates based on previously completed field work. The habitat confirmation count is based on the assumption that the 23 barriers requiring barrier assessments will also require a subsequent confirmation. In the case that some barriers are identified as unsuitable candidates for habitat confirmations, the total cost will be reduced.*
# ```

# %% [markdown]
# ```{include} ../content/appendixb-md.md
# :start-after: "final barrier to pursue for remediation:"
# ```

# %%
data = pd.read_csv('../tables/Table21.csv', index_col=False)

data = data.replace(np.nan, '', regex=True)

last_row = pd.IndexSlice[data.index[data.index == 4], :]

data = data.style.applymap(df_style, subset=last_row).hide_index().set_properties(**{'text-align': 'left'})

data.set_table_styles(
[dict(selector = 'th', props=[('text-align', 'left')])])

glue("Table21", data)
# Out:
# <style  type="text/css" >
#     #T_a84ae510_967e_11ed_8f32_b445066bfd9b th {
#           text-align: left;
#     }#T_a84ae510_967e_11ed_8f32_b445066bfd9brow0_col0,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow0_col1,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow0_col2,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow0_col3,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow1_col0,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow1_col1,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow1_col2,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow1_col3,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow2_col0,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow2_col1,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow2_col2,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow2_col3,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow3_col0,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow3_col1,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow3_col2,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow3_col3{
#             text-align:  left;
#         }#T_a84ae510_967e_11ed_8f32_b445066bfd9brow4_col0,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow4_col1,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow4_col2,#T_a84ae510_967e_11ed_8f32_b445066bfd9brow4_col3{
#             font-weight:  bold;
#             text-align:  left;
#         }</style><table id="T_a84ae510_967e_11ed_8f32_b445066bfd9b" ><thead>    <tr>        <th class="col_heading level0 col0" >Barrier Type</th>        <th class="col_heading level0 col1" >Cost per barrier</th>        <th class="col_heading level0 col2" >Count</th>        <th class="col_heading level0 col3" >Total Cost</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow0_col0" class="data row0 col0" >
#   Rail
#   </td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow0_col1" class="data row0 col1" >
#    $1,700,000
#   </td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow0_col2" class="data row0 col2" >4</td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow0_col3" class="data row0 col3" >
#    $6,800,000
#   </td>
#             </tr>
#             <tr>
#                                 <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow1_col0" class="data row1 col0" >
#   Highway
#   </td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow1_col1" class="data row1 col1" >
#    $5,200,000
#   </td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow1_col2" class="data row1 col2" >9</td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow1_col3" class="data row1 col3" >
#   $46,800,000
#   </td>
#             </tr>
#             <tr>
#                                 <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow2_col0" class="data row2 col0" >
#   Municipal/paved road
#   </td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow2_col1" class="data row2 col1" >
#    $1,500,000
#   </td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow2_col2" class="data row2 col2" >3</td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow2_col3" class="data row2 col3" >
#    $4,500,000
#   </td>
#             </tr>
#             <tr>
#                                 <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow3_col0" class="data row3 col0" >
#   Resource road
#   </td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow3_col1" class="data row3 col1" >
#    $500,000
#   </td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow3_col2" class="data row3 col2" >15</td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow3_col3" class="data row3 col3" >
#    $7,500,000
#   </td>
#             </tr>
#             <tr>
#                                 <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow4_col0" class="data row4 col0" >
#   Total:
#   </td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow4_col1" class="data row4 col1" ></td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow4_col2" class="data row4 col2" >30</td>
#                         <td id="T_a84ae510_967e_11ed_8f32_b445066bfd9brow4_col3" class="data row4 col3" >
#   $65,600,000
#   </td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ```{glue:figure} Table21
# :name: "table21"
#
# *Preliminary barrier remediation cost estimate to reach connectivity goals in the Bulkley River watershed. Cost per barrier values are estimated based on the average cost of previously completed projects. Barrier counts and total costs are subject to change as more information is collected through the implementation of this plan.*
# ```
